# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit
from arps.dca import (
      hyperbolic_equation, 
      get_min_or_max_value_in_column_by_group,
      get_max_initial_production,
      plot_actual_vs_predicted_by_equations,
      remove_nan_and_zeroes_from_columns
)

from arps.fit_arps import execute_arps



from arps.predict_arps import predict_arps
predict_arps(
     prd_time_series='recoil_daily_prod', 
     well_nm='42493327380000', 
     liquid='OIL (BBL)', 
     qi_min=0, 
     b_min=0, 
     di_min=0,
     qi_max=1000, 
     b_max=3, 
     di_max=20,
     sigma_fit=1,
     sigma_pred=1,
     pred_interval=5000
)
# Out:
# [[Model]]
#     Model(hyperbolic_equation)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 128
#     # data points      = 2251
#     # variables        = 3
#     chi-square         = 912012.732
#     reduced chi-square = 405.699614
#     Akaike info crit   = 13521.6329
#     Bayesian info crit = 13538.7903
# [[Variables]]
#     qi:  232.166598 +/- 3.77084439 (1.62%) (init = 1000)
#     b:   0.67107242 +/- 0.03077667 (4.59%) (init = 3)
#     di:  0.00565713 +/- 2.5848e-04 (4.57%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(b, di)  =  0.873
#     C(qi, di) =  0.829
#     C(qi, b)  =  0.573
# R-Square:  0.8085232963905863
# EUR:  97536.31411237271
